# %%
import pandas as pd
import altair as alt
alt.renderers.enable('notebook')

from vega_datasets import data
cars = data.cars()

alt.Chart(cars).mark_point().encode(
    x = 'Horsepower',
    y = 'Miles_per_Gallon',
    color = 'Origin'
).interactive()

# %% [markdown]
# ## Wednesday Demo

# %%
import pandas as pd
import altair as alt

# must use for Jupyter notebook
alt.renderers.enable('notebook')

# load the cars dataset
# can replace with any dataframe
from vega_datasets import data
cars = data.cars()

# determine our column headers
print(cars.columns)
# Out:
# Index(['Acceleration', 'Cylinders', 'Displacement', 'Horsepower',
#        'Miles_per_Gallon', 'Name', 'Origin', 'Weight_in_lbs', 'Year'],
#       dtype='object')

# %%
alt.Chart(cars).mark_point().encode(
    x = 'Horsepower',
    y = 'Miles_per_Gallon',
    color = 'Origin'
).interactive() # basic panning and zooming

# %%
alt.Chart(cars).mark_bar().encode(
    x = 'Name',
    y = 'Cylinders'
)

# %%
alt.Chart(cars).mark_bar().encode(
    x = 'Year',
    y = 'average(Cylinders)'
)

# %%
alt.Chart(cars).mark_bar().encode(
    alt.X('Horsepower', bin = True),
    y = ''
    
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-018cf28a5bca> in <module>
# ----> 1 alt.Chart(cars).mark_hist().encode(
#       2     x = 'Name',
#       3     y = 'Cylinders'
#       4 )
#
# ~/anaconda3/lib/python3.6/site-packages/altair/utils/schemapi.py in __getattr__(self, attr)
#     173             except AttributeError:
#     174                 _getattr = super(SchemaBase, self).__getattribute__
# --> 175             return _getattr(attr)
#     176
#     177     def __setattr__(self, item , val):
#
# AttributeError: 'Chart' object has no attribute 'mark_hist'
